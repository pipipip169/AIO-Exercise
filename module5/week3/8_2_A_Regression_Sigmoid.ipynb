# %% [markdown]
# ## **1. Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

# %% [markdown]
# ## **2. Read dataset**

# %%
dataset_path = 'Auto_MPG_data.csv'
dataset = pd.read_csv(dataset_path)
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0        86.0  2790.0          15.6
# 388  44.0          4          97.0        52.0  2130.0          24.6
# 389  32.0          4         135.0        84.0  2295.0          11.6
# 390  28.0          4         120.0        79.0  2625.0          18.6
# 391  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan  USA
# 0            70       0      0    1
# 1            70       0      0    1
# 2            70       0      0    1
# 3            70       0      0    1
# 4            70       0      0    1
# ..          ...     ...    ...  ...
# 387          82       0      0    1
# 388          82       1      0    0
# 389          82       0      0    1
# 390          82       0      0    1
# 391          82       0      0    1
#
# [392 rows x 10 columns]

# %% [markdown]
# ## **3. Preprocessing data**

# %% [markdown]
# ### **3.1. X, y split**

# %%
X = dataset.drop(columns='MPG').values
y = dataset['MPG'].values

# %% [markdown]
# ### **3.2. Train/val/test split**

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
print(f'Number of training samples: {X_train.shape[0]}')
print(f'Number of val samples: {X_val.shape[0]}')
print(f'Number of test samples: {X_test.shape[0]}')
# Out:
# Number of training samples: 273
# Number of val samples: 79
# Number of test samples: 40

# %% [markdown]
# ### **3.3. Data Normalization**

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %% [markdown]
# ## **4. Create PyTorch DataLoader**

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## **5. Build MLP network**

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
        x = self.linear1(x)
        x = F.sigmoid(x)
        x = self.linear2(x)
        x = F.sigmoid(x)
        out = self.output(x)
        return out.squeeze(1)

# %%
X_train.shape[1]
# Out:
# 9

# %%
input_dims = X_train.shape[1]
output_dims = 1
hidden_dims = 64
lr = 1e-2

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %% [markdown]
# ## **6. Training**

# %%
def r_squared(y_true, y_pred):
    y_true = torch.Tensor(y_true).to(device)
    y_pred = torch.Tensor(y_pred).to(device)
    mean_true = torch.mean(y_true)
    ss_tot = torch.sum((y_true - mean_true) ** 2)
    ss_res = torch.sum((y_true - y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

epochs = 100
train_losses = []
val_losses = []
train_r2 = []
val_r2 = []

# %%
for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    val_target = []
    train_predict = []
    val_predict = []
    model.train()
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        train_predict += outputs.tolist()
        train_target += y_samples.tolist()
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r_squared(train_target, train_predict))
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            val_predict += outputs.tolist()
            val_target += y_samples.tolist()
            loss = criterion(outputs, y_samples)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r_squared(val_target, val_predict))
    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 154.925	Validation loss: 46.922
#
# EPOCH 2:	Training loss: 44.081	Validation loss: 30.159
#
# EPOCH 3:	Training loss: 29.060	Validation loss: 20.040
#
# EPOCH 4:	Training loss: 22.984	Validation loss: 13.163
#
# EPOCH 5:	Training loss: 18.948	Validation loss: 13.374
#
# EPOCH 6:	Training loss: 16.785	Validation loss: 9.556
#
# EPOCH 7:	Training loss: 15.319	Validation loss: 10.238
#
# EPOCH 8:	Training loss: 14.172	Validation loss: 11.682
#
# EPOCH 9:	Training loss: 14.756	Validation loss: 7.594
#
# EPOCH 10:	Training loss: 13.489	Validation loss: 8.973
#
# EPOCH 11:	Training loss: 13.151	Validation loss: 7.037
#
# EPOCH 12:	Training loss: 12.770	Validation loss: 7.129
#
# EPOCH 13:	Training loss: 12.072	Validation loss: 7.801
#
# EPOCH 14:	Training loss: 12.118	Validation loss: 7.527
#
# EPOCH 15:	Training loss: 12.287	Validation loss: 6.851
#
# EPOCH 16:	Training loss: 10.895	Validation loss: 7.964
#
# EPOCH 17:	Training loss: 11.717	Validation loss: 7.548
#
# EPOCH 18:	Training loss: 11.492	Validation loss: 6.619
#
# EPOCH 19:	Training loss: 10.451	Validation loss: 6.469
#
# EPOCH 20:	Training loss: 10.795	Validation loss: 6.903
#
# EPOCH 21:	Training loss: 10.875	Validation loss: 6.294
#
# EPOCH 22:	Training loss: 10.153	Validation loss: 6.611
#
# EPOCH 23:	Training loss: 10.769	Validation loss: 7.842
#
# EPOCH 24:	Training loss: 10.510	Validation loss: 7.146
#
# EPOCH 25:	Training loss: 9.739	Validation loss: 7.677
#
# EPOCH 26:	Training loss: 9.660	Validation loss: 6.058
#
# EPOCH 27:	Training loss: 10.029	Validation loss: 6.745
#
# EPOCH 28:	Training loss: 9.445	Validation loss: 5.700
#
# EPOCH 29:	Training loss: 10.494	Validation loss: 5.877
#
# EPOCH 30:	Training loss: 10.104	Validation loss: 6.753
#
# EPOCH 31:	Training loss: 9.598	Validation loss: 5.872
#
# EPOCH 32:	Training loss: 9.640	Validation loss: 7.292
#
# EPOCH 33:	Training loss: 10.592	Validation loss: 9.323
#
# EPOCH 34:	Training loss: 10.643	Validation loss: 6.684
#
# EPOCH 35:	Training loss: 9.286	Validation loss: 5.738
#
# EPOCH 36:	Training loss: 9.252	Validation loss: 5.299
#
# EPOCH 37:	Training loss: 9.315	Validation loss: 5.976
#
# EPOCH 38:	Training loss: 8.928	Validation loss: 5.978
#
# EPOCH 39:	Training loss: 8.711	Validation loss: 5.794
#
# EPOCH 40:	Training loss: 9.212	Validation loss: 5.248
#
# EPOCH 41:	Training loss: 9.490	Validation loss: 5.565
#
# EPOCH 42:	Training loss: 8.847	Validation loss: 5.732
#
# EPOCH 43:	Training loss: 9.137	Validation loss: 5.334
#
# EPOCH 44:	Training loss: 9.561	Validation loss: 5.103
#
# EPOCH 45:	Training loss: 8.958	Validation loss: 5.013
#
# EPOCH 46:	Training loss: 8.647	Validation loss: 5.712
#
# EPOCH 47:	Training loss: 8.767	Validation loss: 5.000
#
# EPOCH 48:	Training loss: 8.995	Validation loss: 6.083
#
# EPOCH 49:	Training loss: 9.044	Validation loss: 5.028
#
# EPOCH 50:	Training loss: 8.480	Validation loss: 5.078
#
# EPOCH 51:	Training loss: 8.646	Validation loss: 4.926
#
# EPOCH 52:	Training loss: 8.582	Validation loss: 5.053
#
# EPOCH 53:	Training loss: 8.754	Validation loss: 5.244
#
# EPOCH 54:	Training loss: 8.531	Validation loss: 5.471
#
# EPOCH 55:	Training loss: 9.149	Validation loss: 6.853
#
# EPOCH 56:	Training loss: 8.995	Validation loss: 6.070
#
# EPOCH 57:	Training loss: 8.894	Validation loss: 4.938
#
# EPOCH 58:	Training loss: 8.530	Validation loss: 4.841
#
# EPOCH 59:	Training loss: 8.421	Validation loss: 5.013
#
# EPOCH 60:	Training loss: 8.836	Validation loss: 4.832
#
# EPOCH 61:	Training loss: 8.308	Validation loss: 4.829
#
# EPOCH 62:	Training loss: 8.378	Validation loss: 5.566
#
# EPOCH 63:	Training loss: 8.555	Validation loss: 7.654
#
# EPOCH 64:	Training loss: 8.729	Validation loss: 4.910
#
# EPOCH 65:	Training loss: 8.640	Validation loss: 5.632
#
# EPOCH 66:	Training loss: 8.486	Validation loss: 5.329
#
# EPOCH 67:	Training loss: 8.310	Validation loss: 4.997
#
# EPOCH 68:	Training loss: 8.498	Validation loss: 5.764
#
# EPOCH 69:	Training loss: 8.208	Validation loss: 5.033
#
# EPOCH 70:	Training loss: 8.287	Validation loss: 5.772
#
# EPOCH 71:	Training loss: 9.125	Validation loss: 5.876
#
# EPOCH 72:	Training loss: 8.651	Validation loss: 6.275
#
# EPOCH 73:	Training loss: 7.823	Validation loss: 4.695
#
# EPOCH 74:	Training loss: 8.025	Validation loss: 4.749
#
# EPOCH 75:	Training loss: 9.004	Validation loss: 6.441
#
# EPOCH 76:	Training loss: 8.175	Validation loss: 5.011
#
# EPOCH 77:	Training loss: 8.394	Validation loss: 4.813
#
# EPOCH 78:	Training loss: 8.494	Validation loss: 4.993
#
# EPOCH 79:	Training loss: 8.078	Validation loss: 4.950
#
# EPOCH 80:	Training loss: 8.034	Validation loss: 5.630
#
# EPOCH 81:	Training loss: 8.325	Validation loss: 5.660
#
# EPOCH 82:	Training loss: 8.157	Validation loss: 4.935
#
# EPOCH 83:	Training loss: 8.026	Validation loss: 6.007
#
# EPOCH 84:	Training loss: 8.701	Validation loss: 5.716
#
# EPOCH 85:	Training loss: 7.820	Validation loss: 4.794
#
# EPOCH 86:	Training loss: 8.596	Validation loss: 6.474
#
# EPOCH 87:	Training loss: 8.207	Validation loss: 5.149
#
# EPOCH 88:	Training loss: 8.910	Validation loss: 4.920
#
# EPOCH 89:	Training loss: 8.240	Validation loss: 5.085
#
# EPOCH 90:	Training loss: 8.554	Validation loss: 5.140
#
# EPOCH 91:	Training loss: 7.824	Validation loss: 7.159
#
# EPOCH 92:	Training loss: 8.443	Validation loss: 8.841
#
# EPOCH 93:	Training loss: 9.917	Validation loss: 4.911
#
# EPOCH 94:	Training loss: 8.335	Validation loss: 6.406
#
# EPOCH 95:	Training loss: 8.213	Validation loss: 5.547
#
# EPOCH 96:	Training loss: 8.568	Validation loss: 4.690
#
# EPOCH 97:	Training loss: 8.835	Validation loss: 5.361
#
# EPOCH 98:	Training loss: 8.142	Validation loss: 5.195
#
# EPOCH 99:	Training loss: 8.241	Validation loss: 4.716
#
# EPOCH 100:	Training loss: 7.758	Validation loss: 5.606

# %%
train_losses = torch.tensor(train_losses).cpu().numpy()  
val_losses = torch.tensor(val_losses).cpu().numpy()
train_r2 = torch.tensor(train_r2).cpu().numpy()
val_r2 = torch.tensor(val_r2).cpu().numpy()

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_r2, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='R2')
ax[1, 0].set_title('Training R2')

ax[1, 1].plot(val_r2, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='R2')
ax[1, 1].set_title('Validation R2')

plt.show()

# %% [markdown]
# ## **7. Evaluation**

# %%
# Ensure X_val and y_val are on the same device as the model
X_val = X_val.to(device)  # Move X_val to the appropriate device
y_val = y_val.to(device)  # Move y_val to the appropriate device

model.eval()
with torch.no_grad():
    y_hat = model(X_val)  # Compute predictions
    val_set_r2 = r_squared(y_hat, y_val)  # Compute R2 score
    print('Evaluation on validation set:')
    print(f'R2: {val_set_r2}')
# Out:
# Evaluation on validation set:
# R2: 0.8980540037155151

# %%
X_test = X_test.to(device)  # Move X_val to the appropriate device
y_test= y_test.to(device)  # Move y_val to the appropriate device

model.eval()
with torch.no_grad():
    y_hat = model(X_test)
    test_set_r2 = r_squared(y_hat, y_test)
    print('Evaluation on test set:')
    print(f'R2: {test_set_r2}')
# Out:
# Evaluation on test set:
# R2: 0.855358898639679
